# %% [markdown]
# Extracting Dataset using Kaggle API

# %%
# installing the Kaggle library
# !pip install kaggle
# Out:
# ...
#      ---------------------------------------- 0.0/82.7 kB ? eta -:--:--
#      ------------------ ------------------- 41.0/82.7 kB 667.8 kB/s eta 0:00:01
#      ---------------------------------------- 82.7/82.7 kB 1.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#    ---------------------------------------- 0.0/162.8 kB ? eta -:--:--
#    ---------------------------------------- 162.8/162.8 kB 4.8 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/78.2 kB ? eta -:--:--
#    ---------------------------------------- 78.2/78.2 kB 4.5 MB/s eta 0:00:00
# ...
#   Created wheel for kaggle: filename=kaggle-1.6.17-py3-none-any.whl size=105795 sha256=666d156060f0927cd8864d04d97fe60c3e387633a34bba5cb48607615429b49c
#   Stored in directory: c:\users\admin\appdata\local\pip\cache\wheels\a5\6f\7b\837915771e94e181fa3052822926444e34f725ca38e70be77e
# Successfully built kaggle
# ...

# %% [markdown]
# Importing the Dog vs Cat Dataset from Kaggle

# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = '.'  # Directory where kaggle.json exists

# %%
# Kaggle api
# !kaggle competitions download -c dogs-vs-cats
# Out:
# ...
#   0%|          | 0.00/812M [00:00<?, ?B/s]
#   0%|          | 1.00M/812M [00:01<21:19, 665kB/s]
#   0%|          | 2.00M/812M [00:01<10:35, 1.34MB/s]
#   0%|          | 3.00M/812M [00:01<06:36, 2.14MB/s]
#   1%|          | 5.00M/812M [00:02<03:29, 4.03MB/s]
#   1%|          | 7.00M/812M [00:02<02:15, 6.22MB/s]
#   1%|          | 9.00M/812M [00:02<01:43, 8.14MB/s]
#   1%|▏         | 11.0M/812M [00:02<01:21, 10.3MB/s]
#   2%|▏         | 13.0M/812M [00:02<01:12, 11.6MB/s]
#   2%|▏         | 15.0M/812M [00:02<01:03, 13.2MB/s]
#   2%|▏         | 17.0M/812M [00:02<00:58, 14.1MB/s]
#   2%|▏         | 19.0M/812M [00:02<00:54, 15.3MB/s]
#   3%|▎         | 21.0M/812M [00:03<00:53, 15.6MB/s]
#   3%|▎         | 23.0M/812M [00:03<00:51, 16.1MB/s]
#   3%|▎         | 25.0M/812M [00:03<00:50, 16.5MB/s]
#   3%|▎         | 27.0M/812M [00:03<00:50, 16.4MB/s]
#   4%|▎         | 29.0M/812M [00:03<00:47, 17.1MB/s]
#   4%|▍         | 31.0M/812M [00:03<00:49, 16.7MB/s]
# ...

# %%
# extracting the compressed dataset
from zipfile import ZipFile

dataset = 'dogs-vs-cats.zip'

with ZipFile(dataset, 'r') as zip:
  zip.extractall()
  print('The dataset is extracted')
# Out:
# The dataset is extracted

# %%
# extracting the compressed dataset
from zipfile import ZipFile

dataset = 'train.zip'

with ZipFile(dataset, 'r') as zip:
  zip.extractall()
  print('The dataset is extracted')
# Out:
# The dataset is extracted

# %%
import os
# counting the number of files in train folder
path, dirs, files = next(os.walk('train'))
file_count = len(files)
print('Number of images: ', file_count)
# Out:
# Number of images:  25000

# %% [markdown]
# Printing the name of images

# %%
file_names = os.listdir('train/')
print(file_names)
# Out:
# ['cat.0.jpg', 'cat.1.jpg', 'cat.10.jpg', 'cat.100.jpg', 'cat.1000.jpg', 'cat.10000.jpg', 'cat.10001.jpg', 'cat.10002.jpg', 'cat.10003.jpg', 'cat.10004.jpg', 'cat.10005.jpg', 'cat.10006.jpg', 'cat.10007.jpg', 'cat.10008.jpg', 'cat.10009.jpg', 'cat.1001.jpg', 'cat.10010.jpg', 'cat.10011.jpg', 'cat.10012.jpg', 'cat.10013.jpg', 'cat.10014.jpg', 'cat.10015.jpg', 'cat.10016.jpg', 'cat.10017.jpg', 'cat.10018.jpg', 'cat.10019.jpg', 'cat.1002.jpg', 'cat.10020.jpg', 'cat.10021.jpg', 'cat.10022.jpg', 'cat.10023.jpg', 'cat.10024.jpg', 'cat.10025.jpg', 'cat.10026.jpg', 'cat.10027.jpg', 'cat.10028.jpg', 'cat.10029.jpg', 'cat.1003.jpg', 'cat.10030.jpg', 'cat.10031.jpg', 'cat.10032.jpg', 'cat.10033.jpg', 'cat.10034.jpg', 'cat.10035.jpg', 'cat.10036.jpg', 'cat.10037.jpg', 'cat.10038.jpg', 'cat.10039.jpg', 'cat.1004.jpg', 'cat.10040.jpg', 'cat.10041.jpg', 'cat.10042.jpg', 'cat.10043.jpg', 'cat.10044.jpg', 'cat.10045.jpg', 'cat.10046.jpg', 'cat.10047.jpg', 'cat.10048.jpg', 'cat.10049.jpg', 'cat.1005.jp
# ...

# %% [markdown]
# Importing the Dependencies

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from sklearn.model_selection import train_test_split
import os

# %% [markdown]
# Displaying the images of dogs and cats

# %%
# display dog image
img = mpimg.imread('train/dog.12067.jpg')
imgplt = plt.imshow(img)
plt.show()

# %%
# display cat image
img = mpimg.imread('train/cat.10.jpg')
imgplt = plt.imshow(img)
plt.show()

# %%
file_names = os.listdir('train')

for i in range(5):

  name = file_names[i]
  print(name[0:3])
# Out:
# cat
# cat
# cat
# cat
# cat

# %%
file_names = os.listdir('train')

dog_count = 0
cat_count = 0

for img_file in file_names:

  name = img_file[0:3]

  if name == 'dog':
    dog_count += 1

  else:
    cat_count += 1

print('Number of dog images =', dog_count)
print('Number of cat images =', cat_count)
# Out:
# Number of dog images = 12500
# Number of cat images = 12500

# %% [markdown]
# Resizing all the images

# %%
#creating a directory for resized images
os.mkdir('image resized')

# %%
# Create the resized folder if it doesn't exist
os.makedirs(resized_folder, exist_ok=True)

# Get all files from the folder and sort them
all_files = sorted(os.listdir(original_folder))

# Select first 1000 cat files and first 1000 dog files
cat_files = [f for f in all_files if f.startswith('cat.')]
dog_files = [f for f in all_files if f.startswith('dog.')]

# Ensure you don't exceed available images
cat_files = cat_files[:1000]
dog_files = dog_files[:1000]

# Combine the files for processing
selected_files = cat_files + dog_files

# Resize and save the selected files
for i, filename in enumerate(selected_files):
    img_path = os.path.join(original_folder, filename)
    
    # Open, resize, and save the image
    img = Image.open(img_path)
    img = img.resize((224, 224))
    img = img.convert('RGB')
    
    new_img_path = os.path.join(resized_folder, filename)
    img.save(new_img_path)
    
    print(f"Processed {i+1}/{len(selected_files)}: {filename}")

print("Resizing complete!")
# Out:
# Processed 1/2000: cat.0.jpg
# Processed 2/2000: cat.1.jpg
# Processed 3/2000: cat.10.jpg
# Processed 4/2000: cat.100.jpg
# Processed 5/2000: cat.1000.jpg
# Processed 6/2000: cat.10000.jpg
# Processed 7/2000: cat.10001.jpg
# Processed 8/2000: cat.10002.jpg
# Processed 9/2000: cat.10003.jpg
# Processed 10/2000: cat.10004.jpg
# Processed 11/2000: cat.10005.jpg
# Processed 12/2000: cat.10006.jpg
# Processed 13/2000: cat.10007.jpg
# Processed 14/2000: cat.10008.jpg
# Processed 15/2000: cat.10009.jpg
# Processed 16/2000: cat.1001.jpg
# Processed 17/2000: cat.10010.jpg
# Processed 18/2000: cat.10011.jpg
# Processed 19/2000: cat.10012.jpg
# Processed 20/2000: cat.10013.jpg
# Processed 21/2000: cat.10014.jpg
# Processed 22/2000: cat.10015.jpg
# Processed 23/2000: cat.10016.jpg
# Processed 24/2000: cat.10017.jpg
# Processed 25/2000: cat.10018.jpg
# Processed 26/2000: cat.10019.jpg
# Processed 27/2000: cat.1002.jpg
# Processed 28/2000: cat.10020.jpg
# Processed 29/2000: cat.10021.jpg
# ...

# %%
# display resized dog image
img = mpimg.imread('image resized/dog.10294.jpg')
imgplt = plt.imshow(img)
plt.show()

# %%
# display resized cat image
img = mpimg.imread('image resized/cat.0.jpg')
imgplt = plt.imshow(img)
plt.show()

# %% [markdown]
# **Creating labels for resized images of dogs and cats**

# %% [markdown]
# Cat = 0
#
# Dog = 1

# %%
# creaing a for loop to assign labels
filenames = os.listdir('image resized/')


labels = []

for i in range(2000):

  file_name = filenames[i]
  label = file_name[0:3]

  if label == 'dog':
    labels.append(1)

  else:
    labels.append(0)

# %%
print(filenames[0:5])
print(len(filenames))
# Out:
# ['cat.0.jpg', 'cat.1.jpg', 'cat.10.jpg', 'cat.100.jpg', 'cat.1000.jpg']
# 2000

# %%
print(labels[0:5])
print(len(labels))
# Out:
# [0, 0, 0, 0, 0]
# 2000

# %%
# counting the images of dogs and cats out of 2000 images
values, counts = np.unique(labels, return_counts=True)
print(values)
print(counts)
# Out:
# [0 1]
# [1000 1000]

# %% [markdown]
# Converting all the resized images to numpy arrays

# %%
import cv2
import glob

# %%
image_directory = 'image resized/'
image_extension = ['png', 'jpg']

files = []

[files.extend(glob.glob(image_directory + '*.' + e)) for e in image_extension]

dog_cat_images = np.asarray([cv2.imread(file) for file in files])

# %%
print(dog_cat_images)
# Out:
# [[[[ 87 163 205]
#    [ 89 165 207]
#    [ 92 168 210]
#    ...
#    [124 203 246]
#    [122 200 246]
#    [122 200 246]]
#
#   [[ 87 163 205]
#    [ 89 165 207]
#    [ 92 168 210]
#    ...
#    [124 203 246]
#    [123 201 247]
#    [122 200 246]]
#
#   [[ 87 163 205]
#    [ 89 165 207]
#    [ 92 168 210]
#    ...
#    [124 204 245]
#    [123 202 245]
#    [123 202 245]]
#
#   ...
#
#   [[ 55 123 160]
#    [ 55 123 160]
#    [ 56 124 161]
#    ...
#    [  0   1   1]
#    [  0   1   1]
#    [  0   1   1]]
#
#   [[ 53 121 158]
#    [ 54 122 159]
#    [ 55 123 160]
#    ...
#    [  0   1   1]
#    [  0   1   1]
#    [  0   1   1]]
#
#   [[ 52 120 157]
#    [ 52 120 157]
#    [ 53 121 158]
#    ...
#    [  0   1   1]
#    [  0   1   1]
#    [  0   1   1]]]
#
#
#  [[[ 43  43  37]
#    [ 47  47  41]
#    [ 47  47  41]
#    ...
#    [185 205 210]
#    [173 197 203]
#    [164 192 199]]
#
#   [[ 42  42  36]
#    [ 46  46  40]
#    [ 45  45  39]
#    ...
#    [180 200 205]
#    [169 195 201]
# ...

# %%
type(dog_cat_images)
# Out:
# numpy.ndarray

# %%
print(dog_cat_images.shape)
# Out:
# (2000, 224, 224, 3)

# %%
X = dog_cat_images
Y = np.asarray(labels)

# %% [markdown]
# **Train Test Split**

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=2, stratify=Y)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (2000, 224, 224, 3) (1600, 224, 224, 3) (400, 224, 224, 3)

# %% [markdown]
# 1600 = training images
#
# 400 = test images

# %%
# scaling the data
X_train_scaled = X_train/255

X_test_scaled = X_test/255

# %%
print(X_train_scaled)
# Out:
# [[[[0.10196078 0.0745098  0.0627451 ]
#    [0.10196078 0.0745098  0.0627451 ]
#    [0.10588235 0.07843137 0.06666667]
#    ...
#    [0.3372549  0.33333333 0.31764706]
#    [0.32941176 0.3254902  0.30980392]
#    [0.32156863 0.31764706 0.30196078]]
#
#   [[0.10588235 0.07843137 0.06666667]
#    [0.10588235 0.07843137 0.06666667]
#    [0.10588235 0.07843137 0.06666667]
#    ...
#    [0.32941176 0.3254902  0.30980392]
#    [0.32156863 0.31764706 0.30196078]
#    [0.31372549 0.30980392 0.29411765]]
#
#   [[0.10980392 0.08235294 0.07058824]
#    [0.10980392 0.08235294 0.07058824]
#    [0.11372549 0.08627451 0.0745098 ]
#    ...
#    [0.32156863 0.31764706 0.30196078]
#    [0.31372549 0.30980392 0.29411765]
#    [0.30588235 0.30196078 0.28627451]]
#
#   ...
#
#   [[0.77254902 0.69019608 0.68627451]
#    [0.76078431 0.67843137 0.6745098 ]
#    [0.76862745 0.68627451 0.68235294]
#    ...
#    [0.51372549 0.51764706 0.50196078]
#    [0.55294118 0.55686275 0.54117647]
# ...

# %% [markdown]
# **Building the Neural Network**

# %%
import tensorflow as tf
import tensorflow_hub as hub

# %%
mobilenet_model = 'https://tfhub.dev/google/tf2-preview/mobilenet_v2/feature_vector/4'

pretrained_model = hub.KerasLayer(mobilenet_model, input_shape=(224,224,3), trainable=False)

# %%
num_of_classes = 2

model = tf.keras.Sequential([

    pretrained_model,
    tf.keras.layers.Dense(num_of_classes)

])

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# keras_layer_2 (KerasLayer)   (None, 1280)              2257984
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 2562
# ...
# Total params: 2,260,546
# Trainable params: 2,562
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %%
model.compile(
    optimizer = 'adam',
    loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics = ['acc']
)

# %%
model.fit(X_train_scaled, Y_train, epochs=5)
# Out:
# Epoch 1/5
# 50/50 [==============================] - 6s 41ms/step - loss: 0.5273 - acc: 0.7171
# Epoch 2/5
# 50/50 [==============================] - 2s 42ms/step - loss: 0.0965 - acc: 0.9673
# Epoch 3/5
# 50/50 [==============================] - 2s 42ms/step - loss: 0.0611 - acc: 0.9830
# Epoch 4/5
# 50/50 [==============================] - 2s 42ms/step - loss: 0.0462 - acc: 0.9835
# Epoch 5/5
# 50/50 [==============================] - 2s 41ms/step - loss: 0.0407 - acc: 0.9889

# %%
score, acc = model.evaluate(X_test_scaled, Y_test)
print('Test Loss =', score)
print('Test Accuracy =', acc)
# Out:
# 13/13 [==============================] - 1s 39ms/step - loss: 0.0554 - acc: 0.9875
# Test Loss = 0.05544770881533623
# Test Accuracy = 0.987500011920929

# %% [markdown]
# **Predictive System**

# %%
input_image_path = input('Path of the image to be predicted: ')

input_image = cv2.imread(input_image_path)

# Display the image with the window name 'Image'
cv2.imshow('Image', input_image)

input_image_resize = cv2.resize(input_image, (224,224))

input_image_scaled = input_image_resize/255

image_reshaped = np.reshape(input_image_scaled, [1,224,224,3])

input_prediction = model.predict(image_reshaped)

print(input_prediction)

input_pred_label = np.argmax(input_prediction)

print(input_pred_label)

if input_pred_label == 0:
  print('The image represents a Cat')

else:
  print('The image represents a Dog')
